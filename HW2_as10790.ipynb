# %%
import pandas as pd
import os 

DFDATA = os.getenv('DFDATA')

# %%
pwd
# Out:
# u'/wingrdp/homedirs/as10790/PUI2016_as10790'

# %%
import pylab as pl
# %pylab inline

np.set_printoptions(precision=4, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_ind = pd.read_csv(DFDATA + "/8hkx-uppz/1414245842/8hkx-uppz")

# %%
df_ind
# Out:
#                                             INDICATOR    Q1 09     Q2 09  \
# 0                  Downtown Commercial Vacancy Rates      8.1%      8.7%
# 1                              Hotel Occupancy Rates*   68.61%    84.22%
# 2   Operation Scorecard - Percentage of Acceptably...    98.8%     97.5%
# 3   Operation Scorecard - Percentage of Acceptably...    98.2%     99.4%
# 4                   Visitors to Downtown Attractions*  704461%  2272824%
# 5   Average # of Homeless Individuals Encountered ...    2.18%     4.47%
# 6   Number of Homeless encountered by Outreach Wor...     187%      106%
# 7                                   Services Accepted      88%       53%
# 8                                   Services Declined      99%       53%
# 9                                     Public Contacts  164273%   198670%
# 10                           Tons of Litter Collected   341.7%    386.9%
# 11              Daily Average - Crimes Against Person    0.24%      0.2%
# 12            Daily Average - Crimes Against Property    1.71%     1.64%
# 13       Kiosk Information Booth Contacts - City Hall  114150%   112265%
# 14        Kiosk Information Booth Contacts - WTC Site  125388%   166345%
# 15        Kiosk Information Booth Contacts - WFC Site   67800%    94137%
# 16                            Alliance Website Visits  186602%    77272%
# 17                 Website Visits to Mr. Office Space     272%      104%
# 18                     Downtown Connection Ridership   198059%   218660%
# 19                   Average Weekday Subway Ridership  299350%   318246%
# 20  Commercial Leasing Activity Measured in Square...  920395%   482518%
# 21  Total Residential Housing Unit Inventory - Sou...   27305%    27305%
# 22         Conversion Starts Since 1995 (Cumulative)    13276%    13276%
# 23    New Development Starts Since 1995 (Cumulative)     8376%     8376%
# 24  Future and Options Internship Participants (Cu...    3365%     3373%
# 25  Technical Assistance Inquiries from Small Busi...    6459%     6569%
# 26                      Wireless Network Usage Totals    8518%    15847%
# 27                  Bike Around Downtown (Cumulative)    4615%     7454%
# 28  * The Wi-Fi network underwent an extensive upg...      NaN       NaN
#
#        Q3 09     Q4 09
# 0       9.9%      9.6%
# 1      87.8%       86%
# 2      97.8%     99.4%
# 3       100%      100%
# 4   2650642%  1228309%
# 5      2.43%     3.33%
# 6        NaN      239%
# 7        NaN      150%
# 8        NaN      195%
# 9    217154%   141836%
# 10      404%    407.8%
# 11     0.16%      0.2%
# 12     1.45%     2.05%
# 13   118606%    75163%
# 14   199465%   176970%
# 15   115926%   109531%
# 16    70197%   158677%
# 17      160%      102%
# 18   201174%   216626%
# 19   312145%   314796%
# 20  1025570%   862583%
# 21    27305%    27881%
# 22    13276%    13276%
# 23     8376%     8376%
# 24     3429%     3446%
# 25     6670%     6705%
# 26    14985%       NaN
# 27    12612%    20224%
# 28       NaN       NaN

# %%
df_ind.drop(['Q1 09', 'Q2 09'], axis=1, inplace=True)
df_ind.dropna(array = )

# %%
df_ind
# Out:
#                                             INDICATOR     Q3 09     Q4 09
# 0                  Downtown Commercial Vacancy Rates       9.9%      9.6%
# 1                              Hotel Occupancy Rates*     87.8%       86%
# 2   Operation Scorecard - Percentage of Acceptably...     97.8%     99.4%
# 3   Operation Scorecard - Percentage of Acceptably...      100%      100%
# 4                   Visitors to Downtown Attractions*  2650642%  1228309%
# 5   Average # of Homeless Individuals Encountered ...     2.43%     3.33%
# 6   Number of Homeless encountered by Outreach Wor...       NaN      239%
# 7                                   Services Accepted       NaN      150%
# 8                                   Services Declined       NaN      195%
# 9                                     Public Contacts   217154%   141836%
# 10                           Tons of Litter Collected      404%    407.8%
# 11              Daily Average - Crimes Against Person     0.16%      0.2%
# 12            Daily Average - Crimes Against Property     1.45%     2.05%
# 13       Kiosk Information Booth Contacts - City Hall   118606%    75163%
# 14        Kiosk Information Booth Contacts - WTC Site   199465%   176970%
# 15        Kiosk Information Booth Contacts - WFC Site   115926%   109531%
# 16                            Alliance Website Visits    70197%   158677%
# 17                 Website Visits to Mr. Office Space      160%      102%
# 18                     Downtown Connection Ridership    201174%   216626%
# 19                   Average Weekday Subway Ridership   312145%   314796%
# 20  Commercial Leasing Activity Measured in Square...  1025570%   862583%
# 21  Total Residential Housing Unit Inventory - Sou...    27305%    27881%
# 22         Conversion Starts Since 1995 (Cumulative)     13276%    13276%
# 23    New Development Starts Since 1995 (Cumulative)      8376%     8376%
# 24  Future and Options Internship Participants (Cu...     3429%     3446%
# 25  Technical Assistance Inquiries from Small Busi...     6670%     6705%
# 26                      Wireless Network Usage Totals    14985%       NaN
# 27                  Bike Around Downtown (Cumulative)    12612%    20224%
# 28  * The Wi-Fi network underwent an extensive upg...       NaN       NaN
